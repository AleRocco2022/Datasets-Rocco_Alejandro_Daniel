# %% [markdown]
# <a href="https://colab.research.google.com/github/AleRocco2022/Datasets-Rocco_Alejandro_Daniel/blob/main/Desafio_2_Rocco_Alejandro_Daniel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# El desafio 2 consiste en elegir 1 de los datasets del desafio anterior: Por cuestiones de interes personal, elegire el de la fluctuacion del Peso Argentino en relación a la moneda estadounidense Dolar.
# Para comenzar importaremos las librerias necesarias para este desafio y luego importaremos el dataset seleccionado.

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# %%
import os

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df= pd.read_csv('/content/gdrive/MyDrive/AB_NYC_2019.csv')

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# En el siguiente Dataset, trataremos de indagar cual es el zona de New York donde la gente se ubica, las mejores zonas para visitar y cantidad de veces que se accede a los departamentos, casas, segun la epoca del año

# %% [markdown]
# Para realizar una primera lectura rapida, procedemos a mostrar las primeras 05 filas de la tabla.

# %%
#Cargamos las primeras 05 entradas
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#Cargamos las últimas 05 entradas
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# En la siguiente tabla se ofrecen las estadísticas descriptivas de cada columna (valor mínimo, máximo, promedio, cuartiles y conteo de filas)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# Para no alterar el dataset original, hacemos una copia del mismo. El nuevo Dataset lo llamaremos df1

# %%
df1 = df

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# Para poder visualizar los datos del df1, debemos primeramente cambiar el formato de la columna `last_review`, pasarla al formato datetime.

# %%
df1['last_review'] = pd.to_datetime(df1['last_review'])

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# # Gráficos con Matplotlib.

# %%
fig, ax = plt.subplots(figsize=(12,8))
Fecha = df1["last_review"]
Lugar = df1["neighbourhood_group"]
ax.scatter(Fecha, Lugar, alpha=0.7)
ax.set_title("Lugares con mayor interés para alquilar")
ax.set_xlabel("Fecha")
ax.set_ylabel("Lugar")
plt.show()

# %% [markdown]
# De este primer grafico podemos apreciar que la mayoría de la gente se ubica dentro de New York, en los barrios de Manhattan y Brooklyn, dentro de un período de tiempo de análisis que va desde el año 2011 al 2019.

# %%
fig, ax = plt.subplots(figsize=(15,4))
Tipo_de_lugar = df1.groupby('room_type')['calculated_host_listings_count'].count()
ax.bar(Tipo_de_lugar.index, Tipo_de_lugar.values)
ax.set_title("Cantidad de Lugares")
ax.set_ylabel("Recuento de Veces")
ax.set_xlabel("Tipo de Lugar")
plt.show()

# %% [markdown]
# De este segundo gráfico podemos observar que la mayoría de las personas que rentan un lugar en New York, lo hacen en departamentos o casas enteras.

# %%
fig, ax = plt.subplots(figsize=(15,4))
Tipo_de_lugar = df1.groupby('room_type')['price'].mean()
ax.bar(Tipo_de_lugar.index, Tipo_de_lugar.values, alpha=0.7)
ax.set_title("Precios acorde a la habitación")
ax.set_ylabel("Precio promedio")
ax.set_xlabel("Tipo de Lugar")
plt.show()

# %% [markdown]
# En este ejemplo, se está calculando el precio promedio para cada tipo de habitación.

# %%
fig, ax = plt.subplots(figsize=(15,4))
Tipo_de_lugar = df1.groupby('room_type')['price'].mean()
ax.plot(Tipo_de_lugar.index, Tipo_de_lugar.values, alpha=0.7)
ax.set_title("Precios acorde a la habitación")
ax.set_ylabel("Precio promedio")
ax.set_xlabel("Tipo de Lugar")
plt.show()

# %% [markdown]
# En este ejemplo, se está calculando el precio promedio para cada tipo de habitación y se está creando un gráfico de líneas en su lugar.

# %%
room_types = df1['room_type'].value_counts()

fig, ax = plt.subplots(figsize=(15,8))
ax.pie(room_types.values, labels=room_types.index, autopct='%1.1f%%', startangle=100)
ax.set_title("Distribución de tipos de habitación")
plt.show()

# %% [markdown]
# De esta grafico de torta podemos ver que es muy poco provable que la gente que renta lugares en New York, por medio de la aplicación, lo hace en habitaciones compartidas.

# %% [markdown]
# # Gráficos con Seaborn

# %%
plt.figure(figsize=(12,7))

type1valores= df1.groupby('room_type').room_type.count()

plt.title("Cantidad de reservas por tipo")

g = sns.lineplot(x=type1valores.index, y=type1valores, )
g.set_xlabel('Tipo')
g.set_ylabel('Count')
plt.show()

# %% [markdown]
# Este gráfico muestra la cantidad de reservas por tipo de habitación en un formato lineal, con cada tipo de habitación en el eje x y la cantidad de reservas correspondiente en el eje y.

# %%
# Crea una nueva columna que represente la cantidad de días reservados
df1['dias_reservados'] = (df1['last_review'] - df1['last_review']).dt.days

plt.figure(figsize=(12,8))
for room_type in df1['room_type'].unique():
    sns.histplot(df1[df1['room_type'] == room_type]['dias_reservados'], kde=False, label=room_type)
plt.title("Cantidad de días reservados por tipo")
plt.xlabel('Cantidad de días reservados')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
# Agrupa por el nombre del host y cuenta las reservas
df_host = df1.groupby('host_name').count()['number_of_reviews'].reset_index()

# Ordena de mayor a menor
df_host = df_host.sort_values(by='number_of_reviews', ascending=False)

# Toma solo los primeros 10
df_host = df_host.head(10)

# Grafica los resultados
plt.figure(figsize=(12,8))
sns.barplot(x='host_name', y='number_of_reviews', data=df_host)
plt.title("Cantidad de veces que el host reserva un tipo de habitación")
plt.xlabel('Nombre del host')
plt.ylabel('Cantidad de reservas')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Se ha agrupado por el nombre del host y contado la cantidad de reservas, y luego ordenamos los resultados de mayor a menor para tomar solo los primeros 10. Finalmente, graficamos estos resultados usando un gráfico de barras.

# %%
grouped = df1.groupby(['host_name', 'room_type']).count().reset_index()
grouped = grouped[['host_name', 'room_type', 'id']].sort_values(by='id', ascending=False)
grouped = grouped.head(10)

plt.figure(figsize=(12,8))
sns.barplot(x='host_name', y='id', hue='room_type', data=grouped)
plt.title("Cantidad de reservas por host_name y tipo de habitación")
plt.xlabel('Host name')
plt.ylabel('Cantidad de reservas')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# Para visualizar la cantidad de reservas por host_name y por tipo de habitación, se puede agrupar por ambas columnas y calcular la cantidad de filas en cada grupo. Luego, se puede usar un gráfico de barras para visualizar los resultados.

# %%
df2 = pd.DataFrame({'last_review': df1['last_review'], 'neighbourhood_group': df1['neighbourhood_group']})

# Convert the 'last_review' column to a datetime format
df2['last_review'] = pd.to_datetime(df2['last_review'])

# Set the figure size
plt.figure(figsize=(15,12))

# Plot the line chart using the seaborn lineplot method
sns.lineplot(x='last_review', y='neighbourhood_group', data=df2)

# Add a title to the chart
plt.title('Line Plot de últimas reservas en relación a la ubicación')

# Show the chart
plt.show()

# %% [markdown]
# Este gráfico de líneas nos permite visualizar las cantidad de reservas realizadas a través del tiempo en los diferentes barrios de New York, por medio de la aplicación.

# %%
df3 = pd.DataFrame({'neighbourhood_group': df1['neighbourhood_group'],'price': df1['price']})
plt.figure(figsize=(20,15))
sns.boxplot(x='neighbourhood_group', y='price', hue= 'neighbourhood_group', data= df3)
plt.title('Valores de reserva acorde a los distintos lugares')
plt.show()

# %% [markdown]
# Este boxplot, nos permite visualizar los distintos outlyers en las diferentes zonas, si bien el promedio ronda entre las 140 a 160 dólares, hay muchos casos puntuales en Brooklyn, Manhattan y Queens.
