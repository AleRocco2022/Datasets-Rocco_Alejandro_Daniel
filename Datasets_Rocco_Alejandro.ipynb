# %% [markdown]
# <a href="https://colab.research.google.com/github/AleRocco2022/Datasets-Rocco_Alejandro_Daniel/blob/main/Datasets_Rocco_Alejandro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive

# %%
import os

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df1= pd.read_csv('/content/gdrive/MyDrive/USD_ARS.csv')

# %% [markdown]
# El Dataset se refiere a las diferentes cotizaciones que tomo el peso argentino con relación al dolar desde 05-03-2002 al 31-12-2022

# %%
df1
# Out:
#      indice_tiempo  tipo_cambio_bna_vendedor  tipo_cambio_a3500  \
# 0       2002-03-05                       NaN             1.9917
# 1       2002-03-06                       NaN             2.0508
# 2       2002-03-07                       NaN             2.1375
# 3       2002-03-08                       NaN             2.2033
# 4       2002-03-09                       NaN             2.2033
# ...            ...                       ...                ...
# 7602    2022-12-27                    182.50           176.0717
# 7603    2022-12-28                    183.00           176.3800
# 7604    2022-12-29                    183.25           176.7433
# 7605    2022-12-30                    183.25           177.1283
# 7606    2022-12-31                    183.25           177.1283
#
#       tipo_cambio_mae  volumen_mae  tipo_cambio_implicito_en_adrs  \
# 0                 NaN          NaN                       2.180124
# ...

# %% [markdown]
# El Dataset, nombrado como df1, cuenta con 7607 lineas y 18 columnas

# %%
import numpy as np

# %%
df1.head()
# Out:
#   indice_tiempo  tipo_cambio_bna_vendedor  tipo_cambio_a3500  tipo_cambio_mae  \
# 0    2002-03-05                       NaN             1.9917              NaN
# 1    2002-03-06                       NaN             2.0508              NaN
# 2    2002-03-07                       NaN             2.1375              NaN
# 3    2002-03-08                       NaN             2.2033              NaN
# 4    2002-03-09                       NaN             2.2033              NaN
#
#    volumen_mae  tipo_cambio_implicito_en_adrs  futuro_rofex_usd1m  \
# 0          NaN                       2.180124                 NaN
# 1          NaN                       2.222222                 NaN
# 2          NaN                       2.343949                 NaN
# 3          NaN                       2.227778                 NaN
# 4          NaN                       2.227778                 NaN
#
#    interes_abierto_1m  futuro_rofex_usd2m  interes_abierto_2m  \
# ...

# %%
df1.describe()
# Out:
#        tipo_cambio_bna_vendedor  tipo_cambio_a3500  tipo_cambio_mae  \
# count               2981.000000        7607.000000      5296.000000
# mean                  52.835386          22.291423        30.674823
# std                   44.183338          34.897990        38.958473
# min                    8.490000           1.991700         3.012000
# 25%                   15.550000           3.146350         4.336000
# 50%                   38.400000           4.587000         9.433500
# 75%                   87.750000          17.456500        43.300000
# max                  183.250000         177.128300       177.160000
#
#         volumen_mae  tipo_cambio_implicito_en_adrs  futuro_rofex_usd1m  \
# count  3.334000e+03                    7605.000000         5111.000000
# mean   2.181936e+05                      35.331511           32.213111
# std    1.402885e+05                      67.289498           40.168284
# ...

# %%
df2= pd.read_csv('/content/gdrive/MyDrive/covid_19_indonesia')

# %% [markdown]
# El Dataset 2 se refiere a los casos de covid en Indonesia

# %%
df2
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 31817  9/15/2022             ID-SA    Sulawesi Utara         37           0
# 31818  9/15/2022             ID-SB    Sumatera Barat         13           0
# 31819  9/15/2022             ID-SS  Sumatera Selatan         16           0
# 31820  9/15/2022             ID-SU    Sumatera Utara         50           0
# 31821  9/16/2022               IDN         Indonesia       2358          27
#
# ...

# %% [markdown]
# El df2 cuenta con 31822 lineas y 38 columnas y el estudio va desde el 01-03-2020 al 16-09-2022

# %%
df2.shape
# Out:
# (31822, 38)

# %%
df2.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            1             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               75  ... -6.204699                  0.18
# 1               75  ... -6.204699                  0.18
# ...

# %%
df3= pd.read_csv('/content/gdrive/MyDrive/AB_NYC_2019.csv')

# %% [markdown]
# El Dataset 3 se refiere a casos de airbnb en New York
#
# ---

# %%
df3
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# El df3 cuenta con 48895 lineas y 16 columnas

# %%
df3.shape
# Out:
# (48895, 16)

# %%
df3.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...
